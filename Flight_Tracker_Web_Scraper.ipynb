# %% [markdown]
# <a href="https://colab.research.google.com/github/myrondza/Data-Science-Machine-Learning-Deep-Learning-AI-Guide-Algorithms/blob/master/Flight_Tracker_Web_Scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt update
# !apt install chromium-chromedriver
# !pip install selenium
# set options to be headless, ..
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# open it, go to a website, and get results
driver= webdriver.Chrome('chromedriver',options=options)
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,929 kB]
# ...

# %%
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="e9e86229f02f38d03f90cf96f94ce936")>

# %%
# Enter Origin & Destination
org="DXB"
des="BOM"

# %%
from bs4 import BeautifulSoup
driver.get("https://uk.flightaware.com/live/findflight?origin="+org+"&destination="+des)
html = driver.page_source
soup = BeautifulSoup(html)

# %%
table = soup.find_all('table')
df = pd.read_html(str(table))
print(df[0].to_json(orient='records'))
df = df[0]
# Out:
# [{"Airline":"IndiGo","Ident":"IGO62","Aircraft":"A320","Status":"Scheduled (in 8 hours 5 minutes)","Departure":"Fri 09:50\u00a0+04","Unnamed: 5":null,"Arrival":"14:25\u00a0IST Fri"},{"Airline":"IndiGo","Ident":"IGO62","Aircraft":"A320","Status":"Scheduled (in 8 hours 5 minutes)","Departure":"Fri 09:50\u00a0+04","Unnamed: 5":null,"Arrival":"14:25\u00a0IST Fri"},{"Airline":"Emirates","Ident":"UAE504","Aircraft":"B77W","Status":"Scheduled (in 2 hours 10 minutes)","Departure":"Fri 03:55\u00a0+04","Unnamed: 5":null,"Arrival":"08:25\u00a0IST Fri"},{"Airline":"Emirates","Ident":"UAE504","Aircraft":"B77W","Status":"Scheduled (in 2 hours 10 minutes)","Departure":"Fri 03:55\u00a0+04","Unnamed: 5":null,"Arrival":"08:25\u00a0IST Fri"},{"Airline":"Air India Express","Ident":"AXB1248","Aircraft":"B738","Status":"On The Way! \/ Delayed","Departure":"Fri 00:15\u00a0+04","Unnamed: 5":null,"Arrival":"05:53\u00a0IST Fri"},{"Airline":"Air India Express","Ident":"AXB1248","Aircraft":"B738","Status":"On T
# ...

# %%
df
# Out:
#               Airline    Ident  ...     Unnamed: 5        Arrival
# 0              IndiGo    IGO62  ...            NaN  14:25 IST Fri
# 1              IndiGo    IGO62  ...            NaN  14:25 IST Fri
# 2            Emirates   UAE504  ...            NaN  08:25 IST Fri
# 3            Emirates   UAE504  ...            NaN  08:25 IST Fri
# 4   Air India Express  AXB1248  ...            NaN  05:53 IST Fri
# 5   Air India Express  AXB1248  ...            NaN  05:53 IST Fri
# 6            Emirates   UAE500  ...            NaN  02:15 IST Fri
# 7            Emirates   UAE500  ...            NaN  02:15 IST Fri
# 8           Air India   AIC912  ...            NaN  02:25 IST Fri
# 9           Air India   AIC912  ...            NaN  02:25 IST Fri
# 10              GoAir  GOW4412  ...            NaN  01:55 IST Fri
# 11              GoAir  GOW4412  ...            NaN  01:55 IST Fri
# 12           FlyDubai  FDB8003  ...            NaN  22:35 IST Thu
# ...
